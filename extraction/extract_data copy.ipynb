# %%
from bs4 import BeautifulSoup
import requests
import re
import os
from collections import deque
import json

# %%
SAVE_DIR = r"../raw_data"
EXCLUDED_PATH = os.path.join(SAVE_DIR, "excluded_links.json")
DEPTH_LIMIT = 2

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 11.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# %%
SEED = ["https://vi.wikipedia.org/wiki/L%E1%BB%87_Quy%C3%AAn_(ca_s%C4%A9,_sinh_1981)", 
        "https://vi.wikipedia.org/wiki/Miu_L%C3%AA", 
        "https://vi.wikipedia.org/wiki/H%C3%B2a_Minzy",
        "https://vi.wikipedia.org/wiki/M%E1%BB%B9_Linh",
        "https://vi.wikipedia.org/wiki/Only_C",
        "https://vi.wikipedia.org/wiki/JustaTee",
        "https://vi.wikipedia.org/wiki/Ch%E1%BA%BF_Linh",
        "https://vi.wikipedia.org/wiki/%C4%90%C3%A0m_V%C4%A9nh_H%C6%B0ng",
        "https://vi.wikipedia.org/wiki/Tu%E1%BA%A5n_Ng%E1%BB%8Dc"
        ]

# %%
valid_singers = set()

# %%
def remove_characters(text):
    if isinstance(text, str):
        # Bỏ cụm [sửa|sửa mã nguồn]
        cleaned = text.replace("[sửa|sửa mã nguồn]", "")
        # Xoá ngoặc và dấu cách/dấu ngoặc kép ở đầu & cuối
        cleaned = re.sub(r'^[\s\(\)\[\]\'"]+|[\s\(\)\[\]\'"]+$', '', cleaned)
        return cleaned.strip()
    return text

# %%
def get_years(active_years):
    is_active = False
    if not active_years:
        return None, None

    if isinstance(active_years, str):
        active_years = [active_years]

    start_years = []
    end_years = []

    for period in active_years:
        if not period:
            continue
        p = period.strip()

        # Chuẩn hoá các loại dash thành hyphen thường
        p = re.sub(r'[–—−]', '-', p)

        # 🔹 Lấy tất cả năm và cả từ "nay"
        tokens = re.findall(r'\b(?:19|20)\d{2}\b|\b(?:nay|hiện tại|present|now)\b', p, re.IGNORECASE)

        # Nếu không có token nào, thử kiểm tra dạng đặc biệt "2015-"
        if not tokens:
            if re.search(r'\b(?:19|20)\d{2}\b\s*-\s*$', p):
                start = int(re.search(r'(?:19|20)\d{2}', p).group())
                start_years.append(start)
            continue

        # Xử lý token đầu tiên (năm bắt đầu)
        first = tokens[0]
        if re.match(r'(?:19|20)\d{2}', first):
            start_years.append(int(first))

        # Xử lý token cuối cùng (năm tan rã)
        last = tokens[-1]
        if re.match(r'(?:19|20)\d{2}', last):
            end_years.append(int(last))
        elif re.match(r'(nay|hiện tại|present|now)', last, re.IGNORECASE):
            is_active = True
            # nếu là 'nay' thì không có năm tan rã
            pass
        elif len(tokens) == 1:
            # chỉ có một năm, coi là hoạt động trong năm đó
            end_years.append(int(first))

    if not start_years:
        return None, None

    start = min(start_years)
    end = None if is_active else max(end_years)
    return start, end

# %%
def load_excluded_links():
    if os.path.exists(EXCLUDED_PATH):
        with open(EXCLUDED_PATH, "r", encoding="utf-8") as f:
            return set(json.load(f))
    return set()

# %%
def save_excluded_links(excluded_links):
    with open(EXCLUDED_PATH, "w", encoding="utf-8") as f:
        json.dump(sorted(list(excluded_links)), f, ensure_ascii=False, indent=2)

# %%
def crawl_valid_links(url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # ❌ Các phần cần bỏ qua
    stop_headings = ["Chú thích", "Tham khảo", "Liên kết ngoài"]

    content = soup.find('div', id='mw-content-text')
    if not content:
        print("⚠️ Không tìm thấy nội dung chính trong trang!")
        return []

    all_links = []

    for element in content.find_all(['p', 'ul', 'ol', 'div', 'h2', 'h3'], recursive=True):
        # Nếu gặp heading dừng, thì dừng luôn việc duyệt
        if element.name in ['h2', 'h3']:
            heading_text = element.get_text(strip=True)
            if any(stop in heading_text for stop in stop_headings):
                print(f"🛑 Dừng tại mục: {heading_text}")
                break

        # Lấy link trong các đoạn còn lại
        for link in element.find_all('a', href=True):
            href = link['href']
            if href.startswith('/wiki/') and not any(x in href for x in [':', '#']):
                full_url = "https://vi.wikipedia.org" + href
                all_links.append(full_url)

    # Loại bỏ trùng lặp
    all_links = list(dict.fromkeys(all_links))
    print(f"🔍 Tìm thấy {len(all_links)} đường dẫn hợp lệ trong trang chính.")

    excluded_links = load_excluded_links()
    print(f"📂 Bỏ qua {len(excluded_links)} link đã bị loại trước đó...")

    valid_links = []
    new_excluded = set()
    keywords = [
        "ca sĩ việt nam", "nam ca sĩ việt nam", "nữ ca sĩ việt nam",
        "ca sĩ gốc việt", "ca sĩ hải ngoại", "nhạc sĩ việt nam"
    ]

    # Đưa tất cả keywords về dạng chữ thường
    keywords_lower = [k.lower() for k in keywords]

    for link in all_links:
        if link in excluded_links:
            print(f"⏩ Bỏ qua (đã loại trước): {link}")
            continue

        try:
            sub_resp = requests.get(link, headers=headers, timeout=6)
            sub_soup = BeautifulSoup(sub_resp.text, 'html.parser')
            cat_div = sub_soup.find('div', id='mw-normal-catlinks')

            if cat_div:
                cat_text = cat_div.get_text(strip=True).lower()
                if any(k in cat_text for k in keywords_lower):
                    valid_links.append(link)
                    print(f"✅ Giữ lại: {link}")
                else:
                    print(f"❌ Loại bỏ: {link}")
                    new_excluded.add(link)
            else:
                print(f"⚠️ Không tìm thấy danh mục: {link}")
                new_excluded.add(link)

        except Exception as e:
            print(f"⚠️ Lỗi khi truy cập {link}: {e}")
            new_excluded.add(link)

    excluded_links.update(new_excluded)
    save_excluded_links(excluded_links)

    return valid_links

# %%
def crawl_singer_info(start_urls, depth_limit=DEPTH_LIMIT):
    singers = []
    visited = set()  # tránh trùng lặp
    queue = deque([(url, depth_limit) for url in start_urls])

    while queue:
        url, depth = queue.popleft()  # lấy phần tử đầu (BFS)
        if url in visited or depth <= 0:
            continue
        visited.add(url)

        try:
            print(f"Crawling {url} (depth={depth})...")
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')

            # Trỏ vào info box
            info_box = soup.find("table", {"class": "infobox"})
            if not info_box:
                continue

            info_rows = info_box.find_all("tr")
            singer_info = {}
            singer_info['depth'] = depth
            singer_info['name'] = soup.find("h1", {"id": "firstHeading"}).get_text(strip=True)

            for row in info_rows:
                header = row.find("th")
                data = row.find("td")
                if header and data:
                    key = header.get_text(strip=True)

                    # --- TRƯỜNG HỢP 1: Có <div class="hlist"> ---
                    hlist_div = data.find("div", {"class": "hlist"})
                    if hlist_div:
                        items = [li.get_text(strip=True) for li in hlist_div.find_all("li")]
                        singer_info[key] = items
                        continue

                    # --- TRƯỜNG HỢP 2: Có <ul> ---
                    ul_tag = data.find("ul")
                    if ul_tag:
                        items = [li.get_text(strip=True) for li in ul_tag.find_all("li")]
                        singer_info[key] = items
                        continue

                    # --- TRƯỜNG HỢP 3: Có <br> ---
                    if data.find("br"):
                        parts = [text.strip() for text in data.stripped_strings]
                        singer_info[key] = [p for p in parts if p]
                    else:
                        value = data.get_text(separator=' ', strip=True)
                        singer_info[key] = value

            # --- Thêm các trường bổ sung ---
            singer_info['năm thành lập'], singer_info['năm tan rã'] = get_years(singer_info.get('Năm hoạt động'))
            singer_info['link'] = url
            singer_info['relations'] = []

            singers.append(singer_info)

            # --- Thêm các ca sĩ liên quan vào hàng đợi (nếu còn depth) ---
            if depth - 1 > 0:
                colab_links = crawl_valid_links(url)
                singer_info['collaborated_singers'] = colab_links
                for link in colab_links:
                    if link not in visited:
                        queue.append((link, depth - 1))

        except requests.exceptions.RequestException as e:
            print(f"Error fetching {url}: {e}")

    return singers

# %%
singers = crawl_singer_info(SEED)
print(singers)
#save singer to JSON file
# Out:
# Crawling https://vi.wikipedia.org/wiki/L%E1%BB%87_Quy%C3%AAn_(ca_s%C4%A9,_sinh_1981) (depth=2)...
# 🛑 Dừng tại mục: Chú thích
# 🔍 Tìm thấy 194 đường dẫn hợp lệ trong trang chính.
# 📂 Bỏ qua 1736 link đã bị loại trước đó...
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%E1%BB%87_Quy%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%C3%A0_N%E1%BB%99i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Kinh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ca_s%C4%A9
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Pop_rock
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Acoustic
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/V-pop
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/R%26B
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_v%C3%A0ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_%C4%91%E1%BB%8F
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%C3%ACnh_kh%C3%BAc_1954-1975
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_ti%E1%BB%81n_chi%E1%BA%BFn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Bolero_Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BB%8Dng_h%C3%A1t
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%C3%A1t_ch%C3%A8o
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%E1%BB%8Dc_vi%E1%BB%87n_%C3%82m_nh%E1%BA%A1c_Qu%E1%BB%91c_gia_Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%E1%BA%A1i_h%E1%BB%8Dc_V%C4%83n_ho%C3%A1_H%C3%A0_N%E1%BB%99i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BA%A5c_m%C6%A1_c%C3%B3_th%E1%BA%ADt
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%E1%BB%87_Quy%C3%AAn_Acoustic
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Kh%C3%BAc_t%C3%ACnh_x%C6%B0a
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/V%C3%B9ng_t%C3%B3c_nh%E1%BB%9B
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%C3%A0i_kh%C3%B4ng_t%C3%AAn
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/V%C5%A9_Th%C3%A0nh_An
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Th%C3%A1i_Th%E1%BB%8Bnh_(nh%E1%BA%A1c_s%C4%A9)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Tr%E1%BB%8Bnh_C%C3%B4ng_S%C6%A1n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Lam_Ph%C6%B0%C6%A1ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%E1%BA%A7n_t%C6%B0%E1%BB%A3ng_Bolero
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%C3%A2n_t%E1%BB%91_b%C3%AD_%E1%BA%A9n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BB%8Dng_h%C3%A1t_Vi%E1%BB%87t
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1i_Nguy%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%C6%B0%C6%A1ng_Ng%E1%BB%8Dc_Quy%E1%BA%BFn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_%C4%90%E1%BA%A1i_h%E1%BB%8Dc_V%C4%83n_h%C3%B3a_H%C3%A0_N%E1%BB%99i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/C%C3%A0_ph%C3%AA
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Cover
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Thu_Ph%C6%B0%C6%A1ng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ph%C6%B0%C6%A1ng_Thanh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/C%E1%BA%A9m_Ly
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/M%E1%BB%B9_L%E1%BB%87
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/M%E1%BB%B9_T%C3%A2m
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/SEA_Games_22
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Thanh_H%E1%BA%A3i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gala_C%C6%B0%E1%BB%9Di
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%E1%BA%A3o_V%C3%A2n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Phim_truy%E1%BB%81n_h%C3%ACnh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C3%A0i_Truy%E1%BB%81n_h%C3%ACnh_Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Sao_mai_%C4%91i%E1%BB%83m_h%E1%BA%B9n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Sao_Mai_%C4%91i%E1%BB%83m_h%E1%BA%B9n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Vi%E1%BA%BFt_T%C3%A2n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A0nh_ph%E1%BB%91_H%E1%BB%93_Ch%C3%AD_Minh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Album_ph%C3%B2ng_thu
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%C3%A0n_S%C3%B3ng_Xanh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Trung_t%C3%A2m_th%C6%B0%C6%A1ng_m%E1%BA%A1i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Si%C3%AAu_th%E1%BB%8B
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Minh_Tuy%E1%BA%BFt
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Quy%E1%BB%81n_t%C3%A1c_gi%E1%BA%A3
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ph%C3%BA_Quang
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/L%C3%AA_Hi%E1%BA%BFu
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%C3%B9ng_D%C6%B0%C6%A1ng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ng%C3%B4_Thu%E1%BB%B5_Mi%C3%AAn
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/%C4%90o%C3%A0n_Chu%E1%BA%A9n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_V%C4%83n_Th%C6%B0%C6%A1ng_(nh%E1%BA%A1c_s%C4%A9)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ph%E1%BA%A1m_%C4%90%C3%ACnh_Ch%C6%B0%C6%A1ng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/T%C6%B0%E1%BB%9Dng_V%C4%83n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Xu%C3%A2n_Ph%C3%BA
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%E1%BB%93_Ng%E1%BB%8Dc_H%C3%A0
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/%C4%90an_Tr%C6%B0%E1%BB%9Dng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Lam_Tr%C6%B0%E1%BB%9Dng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Tu%E1%BA%A5n_H%C6%B0ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Audiophile
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Jimmii_Nguy%E1%BB%85n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BA%A3i_Grammy
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/CD
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%C3%A0i_h%C3%A1t_y%C3%AAu_th%C3%ADch
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/S%C3%A0i_G%C3%B2n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/T%E1%BB%AB_Huy
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Hu%E1%BB%B3nh_Nh%E1%BA%ADt_T%C3%A2n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Thanh_Ph%C6%B0%C6%A1ng_(nh%E1%BA%A1c_s%C4%A9)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C3%A0n_b%C3%A0
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_phim
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/VTV3
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Bol%C3%A9ro_(v%C5%A9_%C4%91i%E1%BB%87u)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%C3%A0n_M%E1%BA%A1c_T%E1%BB%AD
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%E1%BB%93i_th%C3%B4ng_hai_m%E1%BB%99
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ph%E1%BB%A5_n%E1%BB%AF
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%E1%BB%99i_An
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C3%A0_N%E1%BA%B5ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%C3%ACnh_kh%C3%BAc_v%C6%B0%E1%BB%A3t_th%E1%BB%9Di_gian
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C3%82m_nh%E1%BA%A1c_Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C3%A0m_V%C4%A9nh_H%C6%B0ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ho%C3%A0ng_Th%C3%B9y_Linh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ph%C3%B2ng_tr%C3%A0_ca_nh%E1%BA%A1c
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/M%C6%B0a_r%E1%BB%ABng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Quang_L%C3%AA
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%C3%A0_h%C3%A1t_l%E1%BB%9Bn_Th%C3%A0nh_ph%E1%BB%91_H%E1%BB%93_Ch%C3%AD_Minh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%E1%BB%85_Gi%C3%A1ng_sinh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/H%C6%B0%C6%A1ng_Lan
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Quang_D%C5%A9ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%C3%A0_h%C3%A1t_Ho%C3%A0_B%C3%ACnh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Thu_Minh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Hi%E1%BB%81n_Th%E1%BB%A5c
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Uy%C3%AAn_Linh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%E1%BB%AFu_Ch%C3%A2u
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Trang_m%E1%BA%A1ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%E1%BA%A3n_quy%E1%BB%81n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Zing
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/DVD
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1i_Th%E1%BB%8Bnh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/D%C3%B2ng_th%E1%BB%9Di_gian
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ng%C3%B4_Th%E1%BB%A5y_Mi%C3%AAn
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_Sa_(nh%E1%BA%A1c_s%C4%A9)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ph%E1%BA%A1m_M%E1%BA%A1nh_C%C6%B0%C6%A1ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Quang_D%C5%A9ng_(ca_s%C4%A9)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/D%C6%B0%C6%A1ng_Tri%E1%BB%87u_V%C5%A9
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%E1%BB%93ng_V%C3%A2n_(di%E1%BB%85n_vi%C3%AAn)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/D%C3%A2n_gian_%C4%91%C6%B0%C6%A1ng_%C4%91%E1%BA%A1i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Trung_t%C3%A2m_H%E1%BB%99i_ngh%E1%BB%8B_Qu%E1%BB%91c_gia_Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_tr%E1%BA%BB
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Bolero
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ch%C3%A2u_%C3%82u
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ti%E1%BB%83u_bang
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/M%E1%BB%B9
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Sydney
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Melbourne
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C3%9Ac
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%C3%A0_h%C3%A1t_H%C3%B2a_B%C3%ACnh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%E1%BB%A9c_Tu%E1%BA%A5n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ng%C3%A0y_Qu%E1%BB%91c_t%E1%BA%BF_Ph%E1%BB%A5_n%E1%BB%AF
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%E1%BA%BFt
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ki%E1%BA%BFp_c%E1%BA%A7m_ca
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/M%E1%BA%A1nh_Ph%C3%A1t
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Minh_K%E1%BB%B3
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ho%C3%A0i_Linh_(nh%E1%BA%A1c_s%C4%A9)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1i_Ch%C3%A2u
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%C3%A3ng_phim_Ph%C6%B0%C6%A1ng_Nam
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Tu%E1%BA%A5n_Ng%E1%BB%8Dc
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/5_D%C3%B2ng_K%E1%BA%BB
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Trung_t%C3%A2m_H%E1%BB%99i_ngh%E1%BB%8B_Qu%E1%BB%91c_gia
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Duy%C3%AAn_ph%E1%BA%ADn
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Nh%C6%B0_Qu%E1%BB%B3nh_(ca_s%C4%A9)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A0nh_ph%E1%BB%91_bu%E1%BB%93n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ng%E1%BB%8Dc_S%C6%A1n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Tr%E1%BA%A7n_Thi%E1%BB%87n_Thanh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/C%E1%BA%A9m_V%C3%A2n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/%C3%9D_Lan
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/H%E1%BB%93ng_Nhung
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C6%AF%E1%BB%9Bt_mi
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Di%E1%BB%85m_x%C6%B0a
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Bi%E1%BB%83n_nh%E1%BB%9B
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%C3%A0_h%C3%A1t_L%E1%BB%9Bn_H%C3%A0_N%E1%BB%99i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Thanh_S%C6%A1n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%C3%A0_Ph%C6%B0%C6%A1ng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ho%C3%A0ng_Thi_Th%C6%A1
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Quang_Linh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/L%C3%BD_H%E1%BA%A3i
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Qu%E1%BB%91c_Thi%C3%AAn
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ch%C3%AD_T%C3%A0i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Minh_Nh%C3%AD
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/C%C3%A1t_Ph%C6%B0%E1%BB%A3ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Tr%E1%BA%A5n_Th%C3%A0nh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_Giang
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%E1%BA%A1i_Ngh%C4%A9a
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_V%C4%83n_T%C3%BD
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Long_H%E1%BA%A3i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_%C4%91%C4%A9a_nh%E1%BA%A1c_c%E1%BB%A7a_L%E1%BB%87_Quy%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BB%AFng_b%C3%A0i_kh%C3%B4ng_t%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ca_s%C4%A9_m%E1%BA%B7t_n%E1%BA%A1_(m%C3%B9a_2)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Vi%E1%BB%87t_Anh_(di%E1%BB%85n_vi%C3%AAn)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C6%B0%E1%BB%9Dng_Minh_Giang
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ya_Suy
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/H%C6%B0%C6%A1ng_Giang_(ngh%E1%BB%87_s%C4%A9)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ho%C3%A0ng_Quy%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%E1%BA%A7n_t%C6%B0%E1%BB%A3ng_Bolero_(m%C3%B9a_1)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ng%E1%BB%8Dc_S%C6%A1n_(ca_s%C4%A9)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ca_s%C4%A9_m%E1%BA%B7t_n%E1%BA%A1_(m%C3%B9a_1)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Hoa_h%E1%BA%ADu_Th%E1%BA%BF_gi%E1%BB%9Bi_Vi%E1%BB%87t_Nam_2019
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C3%B4ng_Nhi
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/%C3%81i_Ph%C6%B0%C6%A1ng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Chi_Pu
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Hoa_h%E1%BA%ADu_Th%E1%BA%BF_gi%E1%BB%9Bi_Vi%E1%BB%87t_Nam_2022
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ch%E1%BB%8B_%C4%91%E1%BA%B9p_%C4%91%E1%BA%A1p_gi%C3%B3_r%E1%BA%BD_s%C3%B3ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ng%C3%B4i_sao_B%E1%BA%A1ch_Kim
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Album_v%C3%A0ng_2010
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Zing_Music_Awards
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Wikimedia_Commons
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Facebook
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Wayback_Machine
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/YouTube
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Instagram
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/L%E1%BB%87_Quy%C3%AAn_(ca_s%C4%A9_sinh_1981)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_b%C3%A0i_h%C3%A1t_thu_%C3%A2m_b%E1%BB%9Fi_L%E1%BB%87_Quy%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%E1%BA%A7n_t%C6%B0%E1%BB%A3ng_%C3%A2m_nh%E1%BA%A1c_Vi%E1%BB%87t_Nam_%E2%80%93_Vietnam_Idol
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Thanh_Th%E1%BA%A3o
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Thanh_B%E1%BA%A1ch
# Crawling https://vi.wikipedia.org/wiki/Miu_L%C3%AA (depth=2)...
# 🛑 Dừng tại mục: Chú thích
# 🔍 Tìm thấy 88 đường dẫn hợp lệ trong trang chính.
# 📂 Bỏ qua 1736 link đã bị loại trước đó...
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ninh_Thu%E1%BA%ADn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Kinh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ca_s%C4%A9
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Di%E1%BB%85n_vi%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%E1%BB%ABa_Thi%C3%AAn_Hu%E1%BA%BF
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/V-pop
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Dance-pop
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_ballad
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_R%26B
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BB%8Dng_h%C3%A1t
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Kh%C3%A1nh_H%C3%B2a
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/C%C3%B4ng_gi%C3%A1o_t%E1%BA%A1i_Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Hu%E1%BA%BF
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_Trung_h%E1%BB%8Dc_ph%E1%BB%95_th%C3%B4ng_V%C3%B5_Th%E1%BB%8B_S%C3%A1u,_Th%C3%A0nh_ph%E1%BB%91_H%E1%BB%93_Ch%C3%AD_Minh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%C3%AA_Ho%C3%A0ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BB%AFng_thi%C3%AAn_th%E1%BA%A7n_%C3%A1o_tr%E1%BA%AFng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Kh%E1%BB%95ng_T%C3%BA_Qu%E1%BB%B3nh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/2011
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Zing
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/YanTV
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/2012
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ch%C3%AD_T%C3%A0i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/2013
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%C3%A0_c%C3%B3_5_n%C3%A0ng_ti%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1ng_b%E1%BA%A3y
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/X%C3%AC_Trum_2
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A0nh_L%E1%BB%99c
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Only_C
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ng%C3%A0y_Valentine
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_V%C4%83n_Chung_(nh%E1%BA%A1c_s%C4%A9)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ng%C3%B4_Ki%E1%BA%BFn_Huy
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BB%AFng_m%E1%BA%A3nh_gh%C3%A9p_c%E1%BA%A3m_x%C3%BAc
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Em_l%C3%A0_b%C3%A0_n%E1%BB%99i_c%E1%BB%A7a_anh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Tr%E1%BB%8Bnh_Th%C4%83ng_B%C3%ACnh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/C%C3%B4_g%C3%A1i_%C4%91%E1%BA%BFn_t%E1%BB%AB_h%C3%B4m_qua_(phim)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Thu_Trang
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Tr%E1%BA%A5n_Th%C3%A0nh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ki%E1%BB%81u_Minh_Tu%E1%BA%A5n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/H%E1%BB%A9a_Kim_Tuy%E1%BB%81n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Karik
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Da_Lab
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Lou_Ho%C3%A0ng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Th%E1%BB%A7y_Ti%C3%AAn_(ca_s%C4%A9)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Di%E1%BB%85m_x%C6%B0a
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Wanbi_Tu%E1%BA%A5n_Anh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/%C4%90an_Tr%C6%B0%E1%BB%9Dng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/H%E1%BB%93_Quang_Hi%E1%BA%BFu
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/You_and_I_(phim_H%C3%A0n_Qu%E1%BB%91c)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Angela_Ph%C6%B0%C6%A1ng_Trinh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Yeah1TV
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ph%E1%BA%A1m_V%C4%83n_M%C3%A1ch
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/VTV9
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Duy_Kh%C3%A1nh_(di%E1%BB%85n_vi%C3%AAn)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/VTV3
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/VTC1
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%E1%BB%AFa_tr%C6%B0a_vui_v%E1%BA%BB
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/VTV6
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C6%A0n_gi%E1%BB%9Di_c%E1%BA%ADu_%C4%91%C3%A2y_r%E1%BB%93i!
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%E1%BB%B1_Long
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/C%C3%B4ng_L%C3%BD_(di%E1%BB%85n_vi%C3%AAn)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/HTV7
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ng%C6%B0%E1%BB%9Di_b%C3%AD_%E1%BA%A9n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Isaac_(ca_s%C4%A9)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BB%8Dng_%E1%BA%A3i_gi%E1%BB%8Dng_ai
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%C3%AD_m%E1%BA%ADt_%C4%91%C3%AAm_Ch%E1%BB%A7_Nh%E1%BA%ADt
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ng%C6%B0%E1%BB%9Di_%E1%BA%A5y_l%C3%A0_ai
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/HTV2
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Em_xinh_%22say_hi%22
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Zing_Music_Awards
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/YouTube
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%C3%A0n_s%C3%B3ng_xanh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BA%A3i_th%C6%B0%E1%BB%9Fng_Ng%C3%B4i_Sao_Xanh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/We_Choice_Awards
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%C3%A0n_S%C3%B3ng_Xanh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Znews
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%C3%A1o_Thanh_Ni%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Wayback_Machine
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%C3%A1o_Tu%E1%BB%95i_Tr%E1%BA%BB
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/VnExpress
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/VOV
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Internet_Movie_Database
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Facebook
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%E1%BA%A7n_t%C6%B0%E1%BB%A3ng_V-pop
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Tr%C6%B0%C6%A1ng_Ng%E1%BB%8Dc_%C3%81nh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Jun_V%C5%A9
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Kaity_Nguy%E1%BB%85n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ho%C3%A0ng_Y%E1%BA%BFn_Chibi
# Crawling https://vi.wikipedia.org/wiki/H%C3%B2a_Minzy (depth=2)...
# 🛑 Dừng tại mục: Tham khảo
# 🔍 Tìm thấy 266 đường dẫn hợp lệ trong trang chính.
# 📂 Bỏ qua 1736 link đã bị loại trước đó...
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Qu%E1%BA%BF_T%C3%A2n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Qu%E1%BA%BF_V%C3%B5
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%E1%BA%AFc_Ninh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ca_s%C4%A9
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ng%C6%B0%E1%BB%9Di_d%E1%BA%ABn_ch%C6%B0%C6%A1ng_tr%C3%ACnh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Di%E1%BB%85n_vi%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A0nh_ph%E1%BB%91_H%E1%BB%93_Ch%C3%AD_Minh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/V-pop
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Dance-pop
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/EDM
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ballad
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/R%26B
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Bolero
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Folktronica
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BB%8Dng_h%C3%A1t
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/1985
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/1988
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/1992
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/2000
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ngh%E1%BB%87_thu%E1%BA%ADt
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90am_m%C3%AA
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%C3%A0_N%E1%BB%99i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C3%82m_nh%E1%BA%A1c
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Thanh_nh%E1%BA%A1c
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ph%C3%B2ng_tr%C3%A0_ca_nh%E1%BA%A1c
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/C%C3%A0_ph%C3%AA
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ng%C6%B0%E1%BB%9Di_m%E1%BA%ABu
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%C3%A1o_ch%C3%AD
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Thanh_thi%E1%BA%BFu_ni%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%E1%BB%83_lo%E1%BA%A1i_nh%E1%BA%A1c
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%C3%A0ng_Quan_H%E1%BB%8D_qu%C3%AA_t%C3%B4i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ch%C6%B0%C6%A1ng_tr%C3%ACnh_truy%E1%BB%81n_h%C3%ACnh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Tr%C3%B2_ch%C6%A1i_truy%E1%BB%81n_h%C3%ACnh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ch%C6%B0%C6%A1ng_tr%C3%ACnh_tr%C3%B2_chuy%E1%BB%87n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ho%C3%A0ng_Y%E1%BA%BFn_Chibi
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%E1%BA%A1nh_ph%C3%BAc
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%C3%ACnh_c%E1%BA%A3m
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1ng_m%C6%B0%E1%BB%9Di_m%E1%BB%99t
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/2014
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_s%C4%A9
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_H%E1%BA%A3i_Phong_(nh%E1%BA%A1c_s%C4%A9)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C4%A9a_%C4%91%C6%A1n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/25_th%C3%A1ng_12
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/C%E1%BA%A3m_x%C3%BAc
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1ng_6
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/2015
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Vi%E1%BB%87t_Nam_t%E1%BA%A1i_%C4%90%E1%BA%A1i_h%E1%BB%99i_Th%E1%BB%83_thao_%C4%90%C3%B4ng_Nam_%C3%81_2015
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%E1%BA%A1i_h%E1%BB%99i_Th%E1%BB%83_thao_%C4%90%C3%B4ng_Nam_%C3%81_2015
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1ng_7
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/D%E1%BB%8Bch_v%E1%BB%A5_m%E1%BA%A1ng_x%C3%A3_h%E1%BB%99i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%C3%A0i_h%C3%A1t_y%C3%AAu_th%C3%ADch
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%C3%A2n_v%C4%83n_h%E1%BB%8Dc
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_c%C3%A1c_m%C3%B3n_%C4%83n_Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Mi%E1%BB%81n_B%E1%BA%AFc_(Vi%E1%BB%87t_Nam)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Mi%E1%BB%81n_Trung_(Vi%E1%BB%87t_Nam)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Mi%E1%BB%81n_Nam_(Vi%E1%BB%87t_Nam)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/V%C4%83n_h%C3%B3a
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%E1%BA%A8m_th%E1%BB%B1c_Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1i_Lan
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/10_th%C3%A1ng_9
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ti%C3%AAn_Cookie
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1ng_t%C6%B0
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/2016
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_(m%C3%B9a_th%E1%BB%A9_t%C6%B0)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Yeah1TV
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/YanTV
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/31_th%C3%A1ng_5
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Sinh_nh%E1%BA%ADt
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Kh%E1%BA%AFc_H%C6%B0ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%E1%BA%A1o_di%E1%BB%85n_%C4%91i%E1%BB%87n_%E1%BA%A3nh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Tuy%E1%BB%83n_di%E1%BB%85n_vi%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Thi%E1%BA%BFt_k%E1%BA%BF_b%E1%BB%91i_c%E1%BA%A3nh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ti%E1%BB%81n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1ng_11
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Huy_Tu%E1%BA%A5n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Phim_%C4%91i%E1%BB%87n_%E1%BA%A3nh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Phim_kinh_d%E1%BB%8B
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Phim_h%C3%A0i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/24_th%C3%A1ng_2
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/2017
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90i%E1%BB%87n_%E1%BA%A3nh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/White_Day
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/14_th%C3%A1ng_3
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1ng_n%C4%83m
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Glee_Vietnam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Glee_(ch%C6%B0%C6%A1ng_tr%C3%ACnh_truy%E1%BB%81n_h%C3%ACnh)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Hoa_K%E1%BB%B3
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/18_th%C3%A1ng_8
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1ng_10
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_tr%E1%BB%AF_t%C3%ACnh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Bolero_(%C4%91%E1%BB%8Bnh_h%C6%B0%E1%BB%9Bng)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/C%C3%B4ng_ch%C3%BAa
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%A9c_Ph%C3%BAc
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Erik_(ca_s%C4%A9_Vi%E1%BB%87t_Nam)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/S%C3%A2n_kh%E1%BA%A5u
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Mnet_Asian_Music_Awards
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Mashup_(%C3%A2m_nh%E1%BA%A1c)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%E1%BB%B1_h%C3%A0o
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/N%E1%BB%91t_nh%E1%BA%A1c
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ng%C6%B0%E1%BB%9Di_h%C3%A2m_m%E1%BB%99
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1ng_1
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/2018
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%E1%BA%A3ng_x%E1%BA%BFp_h%E1%BA%A1ng_%C3%A2m_nh%E1%BA%A1c
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1ng_4
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Soundtrack
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/6_th%C3%A1ng_5
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_pop
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Zing_Music_Awards
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ngh%E1%BB%87_s%C4%A9
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ti%E1%BA%BFng_Vi%E1%BB%87t
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ti%E1%BA%BFng_Anh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ti%E1%BA%BFng_Th%C3%A1i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ti%E1%BA%BFng_H%C3%A0n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/25_th%C3%A1ng_7
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/N%C3%A0ng_ti%C3%AAn_c%C3%A1
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_thi%E1%BA%BFu_nhi
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/30_th%C3%A1ng_10
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/YouTube
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/2019
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BB%9Bi_gi%E1%BA%A3i_tr%C3%AD
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_Giang
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Only_C
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Tr%E1%BA%A7n_Ti%E1%BB%83u_Vy
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/C%C6%B0_d%C3%A2n_m%E1%BA%A1ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Th%C3%A1ng_m%E1%BB%99t
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Vai_tr%C3%B2_x%C3%A3_h%E1%BB%99i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Hu%E1%BA%A5n_luy%E1%BB%87n_vi%C3%AAn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Facebook
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ho%C3%A0i_L%C3%A2m
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Trung_Qu%C3%A2n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/%C3%81i_Ph%C6%B0%C6%A1ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Kh%C3%B4ng_th%E1%BB%83_c%C3%B9ng_nhau_su%E1%BB%91t_ki%E1%BA%BFp
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%ADt_B%E1%BA%A3n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Singapore
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C3%9Ac
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C3%A0i_Loan
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%C3%A0n_Qu%E1%BB%91c
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%C3%A0n_S%C3%B3ng_Xanh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/H%E1%BB%A9a_Kim_Tuy%E1%BB%81n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Anh_T%C3%BA_(sinh_1992)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Xu%C3%A2n_h%E1%BA%A1_thu_%C4%91%C3%B4ng_r%E1%BB%93i_l%E1%BA%A1i_xu%C3%A2n_(ch%C6%B0%C6%A1ng_tr%C3%ACnh_truy%E1%BB%81n_h%C3%ACnh)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Uy%C3%AAn_Linh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/V%C4%83n_Mai_H%C6%B0%C6%A1ng
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ph%E1%BA%A1m_Qu%E1%BB%B3nh_Anh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/B%C3%B9i_C%C3%B4ng_Nam
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Lyly
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Always_Remember_Us_This_Way
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Masew
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%E1%BA%AFc_Bling
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Xu%C3%A2n_Hinh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Zing_MP3
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/M%C6%B0a_%C4%91%E1%BB%8F_(phim)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Soprano
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_Minh_C%C6%B0%E1%BB%9Dng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Double2T
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%E1%BA%A3o_Anh_(ca_s%C4%A9)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%C4%83ng_Nh%E1%BA%ADt_Tu%E1%BB%87
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Pop
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Rap
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/D%C3%A2n_gian_%C4%91%C6%B0%C6%A1ng_%C4%91%E1%BA%A1i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%A1c_tr%E1%BA%BB
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Rhymastic
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Kosaka_Daimaou
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/PPAP_(Pen-Pineapple-Apple-Pen)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ch%C3%A2u_%C4%90%C4%83ng_Khoa
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%E1%BA%A3o_Lan
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Justatee
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%C3%ACnh_Gold
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/JustaTee
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/BigDaddy
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Mr._Siro
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Hu%E1%BB%B3nh_Hi%E1%BB%81n_N%C4%83ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Mew_Amazing
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%C4%83ng_Duy_T%C3%A2n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ch%C3%A8o
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%E1%BA%A1ch_Tuy%E1%BA%BFt_(ngh%E1%BB%87_s%C4%A9_c%E1%BA%A3i_l%C6%B0%C6%A1ng)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Genshin_Impact
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Hip-hop
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/D%C3%A2n_ca
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Obito
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/100_ng%C3%A0y_b%C3%AAn_em
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ph%E1%BA%A1m_To%C3%A0n_Th%E1%BA%AFng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_V%C4%83n_Chung_(nh%E1%BA%A1c_s%C4%A9)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C3%A0i_Truy%E1%BB%81n_h%C3%ACnh_Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%C3%A0i_h%C3%A1t_Vi%E1%BB%87t
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Tr%C3%B2_ch%C6%A1i_%C3%A2m_nh%E1%BA%A1c
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%E1%BB%AFa_tr%C6%B0a_vui_v%E1%BA%BB
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_(m%C3%B9a_4)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_(m%C3%B9a_9)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C6%A0n_gi%E1%BB%9Di_c%E1%BA%ADu_%C4%91%C3%A2y_r%E1%BB%93i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/M%E1%BB%99t_tr%C4%83m_tri%E1%BB%87u_m%E1%BB%99t_ph%C3%BAt
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/12_con_gi%C3%A1p_(ch%C6%B0%C6%A1ng_tr%C3%ACnh_truy%E1%BB%81n_h%C3%ACnh)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ai_th%C3%B4ng_minh_h%C6%A1n_h%E1%BB%8Dc_sinh_l%E1%BB%9Bp_5
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C3%A0i_Truy%E1%BB%81n_h%C3%ACnh_Th%C3%A0nh_ph%E1%BB%91_H%E1%BB%93_Ch%C3%AD_Minh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%C3%AD_m%E1%BA%ADt_%C4%91%C3%AAm_Ch%E1%BB%A7_Nh%E1%BA%ADt
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BB%8Dng_%E1%BA%A3i_gi%E1%BB%8Dng_ai
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nhanh_nh%C6%B0_ch%E1%BB%9Bp_(tr%C3%B2_ch%C6%A1i_truy%E1%BB%81n_h%C3%ACnh)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Running_Man_(ch%C6%B0%C6%A1ng_tr%C3%ACnh_truy%E1%BB%81n_h%C3%ACnh_Vi%E1%BB%87t_Nam)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ng%C6%B0%E1%BB%9Di_b%C3%AD_%E1%BA%A9n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/2_ng%C3%A0y_1_%C4%91%C3%AAm_(ch%C6%B0%C6%A1ng_tr%C3%ACnh_truy%E1%BB%81n_h%C3%ACnh_Vi%E1%BB%87t_Nam)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Sao_nh%E1%BA%ADp_ng%C5%A9_2022
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/QPVN
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C3%A0i_Ph%C3%A1t_thanh_-_Truy%E1%BB%81n_h%C3%ACnh_V%C4%A9nh_Long
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/V_Live_(trang_web)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%C3%A0n_s%C3%B3ng_xanh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BA%A3i_Mai_V%C3%A0ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/WeChoice_Awards
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/TikTok_Awards_Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_C%C3%B4ng_Ph%C6%B0%E1%BB%A3ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/BTS
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/VnExpress
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Wayback_Machine
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%C3%A2n_D%C3%A2n_(b%C3%A1o)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/VietNamNet
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Instagram
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_%C4%91%E1%BB%81_c%E1%BB%AD_v%C3%A0_chi%E1%BA%BFn_th%E1%BA%AFng_gi%E1%BA%A3i_th%C6%B0%E1%BB%9Fng_%C3%82m_nh%E1%BA%A1c_C%E1%BB%91ng_hi%E1%BA%BFn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%C3%B9ng_D%C6%B0%C6%A1ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%E1%BB%93_Qu%E1%BB%B3nh_H%C6%B0%C6%A1ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/M%E1%BB%B9_Linh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C3%A0m_V%C4%A9nh_H%C6%B0ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%E1%BB%93_Ng%E1%BB%8Dc_H%C3%A0
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/M%E1%BB%B9_T%C3%A2m
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%E1%BB%A9c_Tu%E1%BA%A5n
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/S%C6%A1n_T%C3%B9ng_M-TP
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Noo_Ph%C6%B0%E1%BB%9Bc_Th%E1%BB%8Bnh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%C3%B4ng_Nhi
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ho%C3%A0ng_Th%C3%B9y_Linh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90en_(rapper)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Soobin_Ho%C3%A0ng_S%C6%A1n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Trang_Ph%C3%A1p
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_(m%C3%B9a_1)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_(m%C3%B9a_2)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_(m%C3%B9a_3)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_(m%C3%B9a_5)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_(m%C3%B9a_6)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_(m%C3%B9a_7)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_(m%C3%B9a_8)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Kh%E1%BB%9Fi_My
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Thanh_Duy
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/B%E1%BA%A1ch_C%C3%B4ng_Khanh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Jun_Ph%E1%BA%A1m
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Duy_Kh%C3%A1nh_(di%E1%BB%85n_vi%C3%AAn)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Nh%E1%BA%ADt_Th%E1%BB%A7y
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Minh_Thu%E1%BA%ADn_(ca_s%C4%A9)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Qu%E1%BB%91c_Thi%C3%AAn
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/H%C3%B9ng_Thu%E1%BA%ADn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/V%C3%B5_T%E1%BA%A5n_Ph%C3%A1t
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Lynk_Lee
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%E1%BA%A1i_Ngh%C4%A9a_(di%E1%BB%85n_vi%C3%AAn)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ph%C6%B0%C6%A1ng_Thanh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Vy_Oanh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Kh%C6%B0%C6%A1ng_Ng%E1%BB%8Dc
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/S%E1%BB%B9_Lu%C3%A2n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ch%C3%AD_Thi%E1%BB%87n_(ca_s%C4%A9)
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Ng%C3%A2n_Qu%E1%BB%B3nh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Duy_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%C3%AA_Th%E1%BB%8B_H%C3%A0_Thu
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/LIME
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_Nh%C3%AD
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_Nh%C3%AD_(m%C3%B9a_1)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_Nh%C3%AD_(m%C3%B9a_2)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_Nh%C3%AD_(m%C3%B9a_3)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/G%C6%B0%C6%A1ng_m%E1%BA%B7t_th%C3%A2n_quen_Nh%C3%AD_(m%C3%B9a_4)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ki%E1%BB%83m_so%C3%A1t_t%C3%ADnh_nh%E1%BA%A5t_qu%C3%A1n
# Crawling https://vi.wikipedia.org/wiki/M%E1%BB%B9_Linh (depth=2)...
# 🛑 Dừng tại mục: Chú thích
# 🔍 Tìm thấy 214 đường dẫn hợp lệ trong trang chính.
# 📂 Bỏ qua 1736 link đã bị loại trước đó...
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_M%E1%BB%B9_Linh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/H%C3%A0_N%E1%BB%99i
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Vi%E1%BB%87t_Nam_D%C3%A2n_ch%E1%BB%A7_C%E1%BB%99ng_h%C3%B2a
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Ca_s%C4%A9
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%C3%A0_vi%E1%BA%BFt_ca_t%E1%BB%AB
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nam_%C4%90%E1%BB%8Bnh
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/Anh_Qu%C3%A2n
# ✅ Giữ lại: https://vi.wikipedia.org/wiki/M%E1%BB%B9_Anh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Diva_Vi%E1%BB%87t_Nam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/V-pop
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/R%26B
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Soul
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Funk
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Classical_crossover
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BB%8Dng_h%C3%A1t
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Piano
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Danh_s%C3%A1ch_ngh%E1%BB%87_s%C4%A9_%C3%A2m_nh%E1%BA%A1c_Vi%E1%BB%87t_Nam_b%C3%A1n_%C4%91%C4%A9a_ch%E1%BA%A1y_nh%E1%BA%A5t
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Danh_hi%E1%BB%87u_nh%E1%BA%A1c_%C4%91%E1%BA%A1i_ch%C3%BAng_%C4%91%C6%B0%E1%BB%A3c_phong_t%E1%BA%B7ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BA%A3i_C%E1%BB%91ng_hi%E1%BA%BFn
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Gi%E1%BA%A3i_Mai_V%C3%A0ng
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/L%C3%A0n_S%C3%B3ng_Xanh
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%E1%BA%A1p_ch%C3%AD_%C4%90%E1%BA%B9p
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/T%C3%B3c_ng%E1%BA%AFn_(album)
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/V%E1%BA%ABn_m%C3%A3i_mong_ch%E1%BB%9D
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Made_in_Vietnam
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Chat_v%E1%BB%9Bi_Mozart
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/M%E1%BB%99t_ng%C3%A0y
# ⏩ Bỏ qua (đã loại trước): https://vi.wikipedia.org/wiki/Nh%E1%BA%ADt_B%E1%BA%A3n
# ...
# Crawling https://vi.wikipedia.org/wiki/Trang_Ph%C3%A1p (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Kh%E1%BB%9Fi_My (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Thanh_Duy (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Jun_Ph%E1%BA%A1m (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Nh%E1%BA%ADt_Th%E1%BB%A7y (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Minh_Thu%E1%BA%ADn_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/H%C3%B9ng_Thu%E1%BA%ADn (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Lynk_Lee (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Vy_Oanh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Kh%C6%B0%C6%A1ng_Ng%E1%BB%8Dc (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/S%E1%BB%B9_Lu%C3%A2n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ch%C3%AD_Thi%E1%BB%87n_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ng%C3%A2n_Qu%E1%BB%B3nh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/LIME (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Anh_Qu%C3%A2n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/M%E1%BB%B9_Anh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Di%E1%BB%87u_Th%C3%BAy (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ng%E1%BB%8Dc_Ch%C3%A2u_(nh%E1%BA%A1c_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/D%C6%B0%C6%A1ng_Th%E1%BB%A5 (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Thanh_T%C3%B9ng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Minh_Qu%C3%A2n_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/B%E1%BA%A3o_Ch%E1%BA%A5n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Huy_Tu%E1%BA%A5n_(nh%E1%BA%A1c_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Anh_Qu%C3%A2n_(nh%E1%BA%A1c_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Thanh_Lam (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%E1%BB%8Dng_T%E1%BA%A5n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Kh%C3%A1nh_Linh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/B%C3%B9i_Anh_Tu%E1%BA%A5n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/V%C5%A9_C%C3%A1t_T%C6%B0%E1%BB%9Dng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/%C4%90inh_M%E1%BA%A1nh_Ninh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/B%C3%ADch_Ph%C6%B0%C6%A1ng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Min_(ca_s%C4%A9_Vi%E1%BB%87t_Nam) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%E1%BA%A7n_Thu_H%C3%A0 (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/D%C6%B0%C6%A1ng_Ho%C3%A0ng_Y%E1%BA%BFn (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Nguy%C3%AAn_Th%E1%BA%A3o_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%C6%B0%C6%A1ng_Ng%E1%BB%8Dc_Ninh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/B%E1%BA%B1ng_Ki%E1%BB%81u (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/C%E1%BA%A9m_V%C3%A2n_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/H%C3%A0_Tr%E1%BA%A7n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%E1%BA%A7n_Ti%E1%BA%BFn (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Thu%E1%BA%ADn_Y%E1%BA%BFn (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Duy_Th%C3%A1i (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/B%E1%BA%A3o_Ph%C3%BAc (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_C%C6%B0%E1%BB%9Dng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/%C4%90%E1%BB%A9c_Tr%C3%AD (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%E1%BA%A7n_M%E1%BA%A1nh_Tu%E1%BA%A5n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/L%C3%AA_Minh_S%C6%A1n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_B%E1%BA%A3o (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Gi%C3%A1ng_Son (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ho%C3%A0i_Sa (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_V%C4%A9nh_Ti%E1%BA%BFn (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Kh%C3%A1nh_Ly (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/%C4%90%C4%83ng_D%C6%B0%C6%A1ng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/H%C3%A0_L%C3%AA (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/H%C3%A0_Anh_Tu%E1%BA%A5n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Marzuz (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Phan_M%E1%BA%A1nh_Qu%E1%BB%B3nh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Orange_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_Ph%C3%BAc_Thi%E1%BB%87n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Minh_H%E1%BA%B1ng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/B%E1%BA%A3o_Thy (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Isaac_(ca_s%C4%A9_Vi%E1%BB%87t_Nam) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/H%C6%B0%C6%A1ng_Tr%C3%A0m (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/%C6%AFng_Ho%C3%A0ng_Ph%C3%BAc (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Emily_(ca_s%C4%A9_Vi%E1%BB%87t_Nam) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Andree_Right_Hand (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Touliver (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Binz_(rapper) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/T%C3%B3c_Ti%C3%AAn_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/ViruSs (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ti%C3%AAn_Ti%C3%AAn (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Suboi (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Wowy (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tlinh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Rhyder (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/D%E1%BA%BF_Cho%E1%BA%AFt_(rapper) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Thanh_Tuy%E1%BB%81n_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Giao_Linh_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Thi%C3%AAn_Trang (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/B%E1%BA%B1ng_Giang_(nh%E1%BA%A1c_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_V%C5%A9 (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/%C4%90an_Nguy%C3%AAn (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Duy_Kh%C3%A1nh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/H%C3%B9ng_C%C6%B0%E1%BB%9Dng_(ngh%E1%BB%87_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ch%C3%A2u_K%E1%BB%B3 (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%C3%BAc_Ph%C6%B0%C6%A1ng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_V%C4%83n_%C4%90%C3%B4ng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%C6%B0%C6%A1ng_Ho%C3%A0ng_Xu%C3%A2n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Nh%E1%BA%ADt_Ng%C3%A2n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/M%E1%BB%99ng_Long (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Thanh_Phong_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ph%C6%B0%E1%BB%A3ng_Mai (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tu%E1%BA%A5n_V%C5%A9 (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/S%C6%A1n_Tuy%E1%BB%81n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ph%C6%B0%C6%A1ng_Dung (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Th%C3%A1i_Ch%C3%A2u_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Phi_Nhung (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/B%C4%83ng_Ch%C3%A2u (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_V%C5%A9_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/%C4%90inh_Vi%E1%BB%87t_Lang (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%E1%BB%8Bnh_L%C3%A2m_Ng%C3%A2n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/V%C4%83n_Gi%E1%BA%A3ng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Hu%E1%BB%B3nh_Anh_(nh%E1%BA%A1c_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/L%C3%AA_Minh_B%E1%BA%B1ng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ng%C3%A2n_Giang_(nh%E1%BA%A1c_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Vinh_S%E1%BB%AD (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Thanh_B%C3%ACnh_(nh%E1%BA%A1c_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Y_V%C5%A9 (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Anh_B%E1%BA%B1ng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/T%C3%BA_Nhi (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%E1%BA%A7m_T%E1%BB%AD_Thi%C3%AAng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/T%C3%A2m_Anh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ph%E1%BA%A1m_Th%E1%BA%BF_M%E1%BB%B9 (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/L%C3%AA_Tr%E1%BB%8Dng_Nguy%E1%BB%85n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ng%E1%BB%8Dc_S%C6%A1n_(nh%E1%BA%A1c_s%C4%A9_tr%C6%B0%E1%BB%9Bc_1975) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%E1%BA%A7n_Tr%E1%BB%8Bnh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Huy_Phong (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/H%E1%BB%93ng_Ng%E1%BB%8Dc_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Siu_Black (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/%C3%81nh_Tuy%E1%BA%BFt (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/L%C3%AA_C%C3%A1t_Tr%E1%BB%8Dng_L%C3%BD (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/T%C3%B4_Thanh_T%C3%B9ng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/B%E1%BA%A3o_Y%E1%BA%BFn (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Duy_M%E1%BA%A1nh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/H%C6%B0%C6%A1ng_Giang_Idol (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/L%C3%AA_Uy%C3%AAn (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%C3%BAc_Nh%C3%A2n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%C3%BAc_H%E1%BB%93 (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_%C3%81nh_9 (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/WanBi_Tu%E1%BA%A5n_Anh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/V%C3%A2n_Kh%C3%A1nh_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Nguy%C3%AAn_V%C5%A9_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Thanh_Th%C3%BAy_(ca_s%C4%A9_sinh_1977) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ph%C6%B0%C6%A1ng_M%E1%BB%B9_Chi (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_Thi%E1%BB%87n_Nh%C3%A2n_(Gi%E1%BB%8Dng_h%C3%A1t_Vi%E1%BB%87t_nh%C3%AD) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/H%E1%BB%93_V%C4%83n_C%C6%B0%E1%BB%9Dng_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ph%C6%B0%C6%A1ng_Anh_Bolero (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/T%E1%BB%91_My (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ph%C6%B0%C6%A1ng_Anh_(ca_s%C4%A9_sinh_1993) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Jack_(ca_s%C4%A9_Vi%E1%BB%87t_Nam) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Thanh_Th%E1%BA%A3o_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/L%E1%BB%AF_Li%C3%AAn (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/B%C3%ADch_Chi%C3%AAu (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Anh_T%C3%BA_(sinh_1950) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Kh%C3%A1nh_H%C3%A0_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/L%C6%B0u_B%C3%ADch (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Th%C3%A1i_Hi%E1%BB%81n (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/T%E1%BA%A5n_Minh (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/H%E1%BB%93_Trung_D%C5%A9ng (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Th%C3%A1i_Th%E1%BA%A3o (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Ph%E1%BA%A1m_Duy (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Tr%E1%BA%A7n_Th%C3%A1i_H%C3%B2a (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Thanh_H%C3%A0_(ca_s%C4%A9) (depth=1)...
# Crawling https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_Cao_K%E1%BB%B3_Duy%C3%AAn (depth=1)...
# [{'depth': 2, 'name': 'Lệ Quyên (ca sĩ, sinh 1981)', 'Sinh': ['Vũ Lệ Quyên', '2 tháng 4, 1981', '(44\xa0tuổi)', 'Hà Nội', ',', 'Việt Nam'], 'Quốc tịch': 'Việt Nam', 'Tên khác': 'Thiên Nga Đen', 'Dân tộc': 'Kinh', 'Nghề nghiệp': 'Ca sĩ', 'Năm hoạt động': '1999\xa0– nay [ 1 ]', 'Phối ngẫu': ['Lê Đức Huy', '(cưới\xa02011\u2060–\u2060', 'ld.', '2020)'], 'Con cái': '1', 'Giải thưởng': 'Danh sách', 'Website': 'Facebook', 'Thể loại': ['Pop rock', 'Acoustic', 'V-pop', 'R&B', 'Dân gian đương đại', 'Nhạc vàng', 'Nhạc đỏ', 'Tình khúc 1954-1975', 'Nhạc tiền chiến', 'Bolero'], 'Nhạc cụ': 'Giọng hát', 'năm thành lập': 1999, 'năm tan rã': None, 'link': 'https://vi.wikipedia.org/wiki/L%E1%BB%87_Quy%C3%AAn_(ca_s%C4%A9,_sinh_1981)', 'relations': [], 'collaborated_singers': ['https://vi.wikipedia.org/wiki/V%C5%A9_Th%C3%A0nh_An', 'https://vi.wikipedia.org/wiki/Th%C3%A1i_Th%E1%BB%8Bnh_(nh%E1%BA%A1c_s%C4%A9)', 'https://vi.wikipedia.org/wiki/Tr%E1%BB%8Bnh_C%C3%B4ng_S%C6%A1n', 'https://vi.wikipedia.org/wiki/Lam_Ph%C6%B0%C6%A1ng', 'https://vi.wikipedia.org/wiki/Thu_Ph%C6%B0%C6%A1ng', 'https://vi.wikipedia.org/wiki/Ph%C6%B0%C6%A1ng_Thanh', 'https://vi.wikipedia.org/wiki/C%E1%BA%A9m_Ly', 'https://vi.wikipedia.org/wiki/Minh_Tuy%E1%BA%BFt', 'https://vi.wikipedia.org/wiki/L%C3%AA_Hi%E1%BA%BFu', 'https://vi.wikipedia.org/wiki/Ng%C3%B4_Thu%E1%BB%B5_Mi%C3%AAn', 'https://vi.wikipedia.org/wiki/%C4%90o%C3%A0n_Chu%E1%BA%A9n', 'https://vi.wikipedia.org/wiki/Nguy%E1%BB%85n_V%C4%83n_Th%C6%B0%C6%A1ng_(nh%E1%BA%A1c_s%C4%A9)', 'https://vi.wikipedia.org/wiki/Ph%E1%BA%A1m_%C4%90%C3%ACnh_Ch%C6%B0%C6%A1ng', 'https://vi.wikipedia.org/wiki/T%C6%B0%E1%BB%9Dng_V%C4%83n', 'https://vi.wikipedia.org/wiki/%C4%90an_Tr%C6%B0%E1%BB%9Dng', 'https://vi.wikipedia.org/wiki/Lam_Tr%C6%B0%E1%BB%9Dng', 'https://vi.wikipedia.org/wiki/Tu%E1%BA%A5n_H%C6%B0ng', 'https://vi.wikipedia.org/wiki/Jimmii_Nguy%E1%BB%85n', 'https://vi.wikipedia.org/wiki/T%E1%BB%AB_Huy', 'https://vi.wikipedia.org/wiki/Hu%E1%BB%B3nh_Nh%E1%BA%ADt_T%C3%A2n', 'https://vi.wikipedia.org/wiki/Quang_L%C3%AA', 'https://vi.wikipedia.org/wiki/H%C6%B0%C6%A1ng_Lan', 'https://vi.wikipedia.org/wiki/Thu_Minh', 'https://vi.wikipedia.org/wiki/Hi%E1%BB%81n_Th%E1%BB%A5c', 'https://vi.wikipedia.org/wiki/Uy%C3%AAn_Linh', 'https://vi.wikipedia.org/wiki/Ng%C3%B4_Th%E1%BB%A5y_Mi%C3%AAn', 'https://vi.wikipedia.org/wiki/Tr%C6%B0%E1%BB%9Dng_Sa_(nh%E1%BA%A1c_s%C4%A9)', 'https://vi.wikipedia.org/wiki/Ph%E1%BA%A1m_M%E1%BA%A1nh_C%C6%B0%C6%A1ng', 'https://vi.wikipedia.org/wiki/D%C6%B0%C6%A1ng_Tri%E1%BB%87u_V%C5%A9', 'https://vi.wikipedia.org/wiki/M%E1%BA%A1nh_Ph%C3%A1t', 'https://vi.wikipedia.org/wiki/Minh_K%E1%BB%B3', 'https://vi.wikipedia.org/wiki/Ho%C3%A0i_Linh_(nh%E1%BA%A1c_s%C4%A9)', 'https://vi.wikipedia.org/wiki/Tu%E1%BA%A5n_Ng%E1%BB%8Dc', 'https://vi.wikipedia.org/wiki/Nh%C6%B0_Qu%E1%BB%B3nh_(ca_s%C4%A9)', 'https://vi.wikipedia.org/wiki/Tr%E1%BA%A7n_Thi%E1%BB%87n_Thanh', 'https://vi.wikipedia.org/wiki/%C3%9D_Lan', 'https://vi.wikipedia.org/wiki/H%E1%BB%93ng_Nhung', 'https://vi.wikipedia.org/wiki/Ho%C3%A0ng_Thi_Th%C6%A1', 'https://vi.wikipedia.org/wiki/L%C3%BD_H%E1%BA%A3i', 'https://vi.wikipedia.org/wiki/Qu%E1%BB%91c_Thi%C3%AAn', 'https://vi.wikipedia.org/wiki/Ch%C3%AD_T%C3%A0i', 'https://vi.wikipedia.org/wiki/Ya_Suy', 'https://vi.wikipedia.org/wiki/H%C6%B0%C6%A1ng_Giang_(ngh%E1%BB%87_s%C4%A9)', 'https://vi.wikipedia.org/wiki/Ho%C3%A0ng_Quy%C3%AAn', 'https://vi.wikipedia.org/wiki/Ng%E1%BB%8Dc_S%C6%A1n_(ca_s%C4%A9)', 'https://vi.wikipedia.org/wiki/%C3%81i_Ph%C6%B0%C6%A1ng', 'https://vi.wikipedia.org/wiki/Chi_Pu', 'https://vi.wikipedia.org/wiki/L%E1%BB%87_Quy%C3%AAn_(ca_s%C4%A9_sinh_1981)']}, {'depth': 2, 'name': 'Miu Lê', 'Sinh': ['Lê Ánh Nhật', '5 tháng 7, 1991', '(34\xa0tuổi)', 'Ninh Thuận', ',', 'Việt Nam'], 'Quốc tịch': 'Việt Nam', 'Dân tộc': 'Kinh', 'Nghề nghiệp': ['Ca sĩ', 'Diễn viên'], 'Năm hoạt động': '2009–nay', 'Quê quán': 'Thừa Thiên Huế , Việt Nam', 'Bạn đời': 'Trần Hoàng Nam', 'Giải thưởng': 'Danh sách', 'Thể loại': ['V-pop', 'dance-p ...

# %%
def identify_relationships(singers):
    for singer in singers:
        for link in singer.get('collaborated_singers', []):
            colab_singer = next((s for s in singers if s['link'] == link), None)
            if colab_singer:
                is_same_genre = False  
                for genre in singer.get("Thể loại", []):
                    if "Thể loại" in colab_singer and genre in colab_singer["Thể loại"]:
                        is_same_genre = True
                        break
                if is_same_genre:
                    singer['relations'].append({
                        'singer_link': link,
                        'type': 'same_genre'
                    })
                    colab_singer['relations'].append({
                        'singer_link': singer['link'],
                        'type': 'same_genre'
                    })
                else:
                    singer['relations'].append({
                        'singer_link': link,
                        'type': 'collaborated'
                    })
                    colab_singer['relations'].append({
                        'singer_link': singer['link'],
                        'type': 'collaborated'
                    })

# %%
identify_relationships(singers)

# %%
# Danh sách toàn bộ các tỉnh/thành phố ở Việt Nam trước xác nhập
list_of_provinces = [
    "An Giang", "Bà Rịa - Vũng Tàu", "Bắc Giang", "Bắc Kạn", "Bạc Liêu", "Bắc Ninh",
    "Bến Tre", "Bình Định", "Bình Dương", "Bình Phước", "Bình Thuận", "Cà Mau",
    "Cần Thơ", "Cao Bằng", "Đà Nẵng", "Đắk Lắk", "Đắk Nông", "Điện Biên", "Đồng Nai",
    "Đồng Tháp", "Gia Lai", "Hà Giang", "Hà Nam", "Hà Nội", "Hà Tĩnh", "Hải Dương",
    "Hải Phòng", "Hậu Giang", "Hòa Bình", "Hưng Yên", "Khánh Hòa", "Kiên Giang",
    "Kon Tum", "Lai Châu", "Lâm Đồng", "Lạng Sơn", "Lào Cai", "Long An", "Nam Định",
    "Nghệ An", "Ninh Bình", "Ninh Thuận", "Phú Thọ", "Phú Yên", "Quảng Bình",
    "Quảng Nam", "Quảng Ngãi", "Quảng Ninh", "Quảng Trị", "Sóc Trăng", "Sơn La",
    "Tây Ninh", "Thái Bình", "Thái Nguyên", "Thanh Hóa", "Thừa Thiên Huế", "Tiền Giang",
    "TP. Hồ Chí Minh", "Trà Vinh", "Tuyên Quang", "Vĩnh Long", "Vĩnh Phúc", "Yên Bái", "Đà Lạt", "Sài Gòn"
]

# %%
for singer in singers:
    if "Quê quán" not in singer or not singer["Quê quán"]:
        sinh_info = singer.get("Sinh", [])
        if isinstance(sinh_info, list):
            sinh_text = " ".join(sinh_info)
        else:
            sinh_text = str(sinh_info)

        # Chuyển về chữ thường để so sánh không phân biệt hoa thường
        sinh_lower = sinh_text.lower()

        matched_province = None
        for province in list_of_provinces:
            if province.lower() in sinh_lower:
                matched_province = province
                break

        if matched_province:
            singer["Quê quán"] = matched_province
            print(f"✅ {singer.get('name', 'Không rõ tên')}: tìm thấy quê quán {matched_province}")
        else:
            print(f"⚠️ {singer.get('name', 'Không rõ tên')}: không xác định được quê quán")
# Out:
# ✅ Lệ Quyên (ca sĩ, sinh 1981): tìm thấy quê quán Hà Nội
# ✅ Hòa Minzy: tìm thấy quê quán Bắc Ninh
# ✅ Only C: tìm thấy quê quán Đà Nẵng
# ✅ JustaTee: tìm thấy quê quán Hà Nội
# ⚠️ Chế Linh: không xác định được quê quán
# ⚠️ Tuấn Ngọc: không xác định được quê quán
# ✅ Vũ Thành An: tìm thấy quê quán Nam Định
# ⚠️ Thái Thịnh (nhạc sĩ): không xác định được quê quán
# ✅ Lam Phương: tìm thấy quê quán Kiên Giang
# ✅ Thu Phương: tìm thấy quê quán Hải Phòng
# ✅ Phương Thanh: tìm thấy quê quán Thanh Hóa
# ⚠️ Minh Tuyết: không xác định được quê quán
# ✅ Lê Hiếu: tìm thấy quê quán Hà Nội
# ✅ Ngô Thụy Miên: tìm thấy quê quán Hải Phòng
# ✅ Đoàn Chuẩn: tìm thấy quê quán Hải Phòng
# ⚠️ Nguyễn Văn Thương (nhạc sĩ): không xác định được quê quán
# ⚠️ Phạm Đình Chương: không xác định được quê quán
# ✅ Tường Văn: tìm thấy quê quán Hà Nội
# ⚠️ Lam Trường: không xác định được quê quán
# ✅ Tuấn Hưng: tìm thấy quê quán Hà Nội
# ⚠️ Jimmii Nguyễn: không xác định được quê quán
# ✅ Từ Huy: tìm thấy quê quán Quảng Nam
# ⚠️ Huỳnh Nhật Tân: không xác định được quê quán
# ⚠️ Quang Lê: không xác định được quê quán
# ⚠️ Hương Lan: không xác định được quê quán
# ✅ Thu Minh: tìm thấy quê quán Hà Nội
# ⚠️ Hiền Thục: không xác định được quê quán
# ⚠️ Uyên Linh: không xác định được quê quán
# ✅ Ngô Thụy Miên: tìm thấy quê quán Hải Phòng
# ✅ Trường Sa (nhạc sĩ): tìm thấy quê quán Ninh Bình
# ⚠️ Phạm Mạnh Cương: không xác định được quê quán
# ✅ Dương Triệu Vũ: tìm thấy quê quán Khánh Hòa
# ⚠️ Mạnh Phát: không xác định được quê quán
# ⚠️ Minh Kỳ: không xác định được quê quán
# ⚠️ Hoài Linh (nhạc sĩ): không xác định được quê quán
# ✅ Như Quỳnh (ca sĩ): tìm thấy quê quán Quảng Trị
# ⚠️ Trần Thiện Thanh: không xác định được quê quán
# ⚠️ Ý Lan: không xác định được quê quán
# ✅ Hồng Nhung: tìm thấy quê quán Hà Nội
# ⚠️ Hoàng Thi Thơ: không xác định được quê quán
# ⚠️ Lý Hải: không xác định được quê quán
# ⚠️ Chí Tài: không xác định được quê quán
# ⚠️ Ya Suy: không xác định được quê quán
# ✅ Hương Giang Idol: tìm thấy quê quán Hà Nội
# ⚠️ Hoàng Quyên: không xác định được quê quán
# ⚠️ Ái Phương: không xác định được quê quán
# ✅ Lệ Quyên (ca sĩ, sinh 1981): tìm thấy quê quán Hà Nội
# ⚠️ Khổng Tú Quỳnh: không xác định được quê quán
# ⚠️ Ngô Kiến Huy: không xác định được quê quán
# ⚠️ Trịnh Thăng Bình: không xác định được quê quán
# ⚠️ Hứa Kim Tuyền: không xác định được quê quán
# ✅ Lou Hoàng: tìm thấy quê quán Hà Nội
# ✅ Thủy Tiên (ca sĩ): tìm thấy quê quán Kiên Giang
# ⚠️ WanBi Tuấn Anh: không xác định được quê quán
# ✅ Hồ Quang Hiếu: tìm thấy quê quán Đắk Lắk
# ⚠️ Angela Phương Trinh: không xác định được quê quán
# ✅ Isaac (ca sĩ): tìm thấy quê quán Cần Thơ
# ✅ Trương Ngọc Ánh: tìm thấy quê quán Hà Nội
# ✅ Hoàng Yến Chibi: tìm thấy quê quán Hà Nội
# ⚠️ Nguyễn Hải Phong (nhạc sĩ): không xác định được quê quán
# ✅ Tiên Cookie: tìm thấy quê quán Hà Nội
# ✅ Khắc Hưng: tìm thấy quê quán Yên Bái
# ✅ Huy Tuấn: tìm thấy quê quán Quảng Ninh
# ✅ Đức Phúc: tìm thấy quê quán Hà Nội
# ✅ Erik (ca sĩ Việt Nam): tìm thấy quê quán Hà Nội
# ✅ Trung Quân: tìm thấy quê quán Lâm Đồng
# ✅ Anh Tú (sinh 1992): tìm thấy quê quán Thái Bình
# ✅ Phạm Quỳnh Anh: tìm thấy quê quán Hà Nội
# ✅ Bùi Công Nam: tìm thấy quê quán Đắk Lắk
# ✅ Lyly: tìm thấy quê quán Đà Nẵng
# ✅ Soobin Hoàng Sơn: tìm thấy quê quán Hà Nội
# ✅ Trang Pháp: tìm thấy quê quán Hà Nội
# ✅ Khởi My: tìm thấy quê quán Đồng Nai
# ✅ Thanh Duy: tìm thấy quê quán Trà Vinh
# ⚠️ Jun Phạm: không xác định được quê quán
# ✅ Nhật Thủy: tìm thấy quê quán Nam Định
# ⚠️ Minh Thuận (ca sĩ): không xác định được quê quán
# ⚠️ Hùng Thuận: không xác định được quê quán
# ✅ Vy Oanh: tìm thấy quê quán Bình Thuận
# ✅ Khương Ngọc: tìm thấy quê quán Khánh Hòa
# ⚠️ Sỹ Luân: không xác định được quê quán
# ⚠️ Chí Thiện (ca sĩ): không xác định được quê quán
# ⚠️ Ngân Quỳnh: không xác định được quê quán
# ⚠️ LIME: không xác định được quê quán
# ✅ Anh Quân: tìm thấy quê quán Hà Nội
# ✅ Mỹ Anh: tìm thấy quê quán Hà Nội
# ⚠️ Diệu Thúy: không xác định được quê quán
# ✅ Ngọc Châu (nhạc sĩ): tìm thấy quê quán Hà Nội
# ✅ Dương Thụ: tìm thấy quê quán Hà Nội
# ✅ Thanh Tùng: tìm thấy quê quán Khánh Hòa
# ✅ Minh Quân (ca sĩ): tìm thấy quê quán Hà Nội
# ✅ Bảo Chấn: tìm thấy quê quán Thừa Thiên Huế
# ✅ Huy Tuấn: tìm thấy quê quán Quảng Ninh
# ✅ Anh Quân: tìm thấy quê quán Hà Nội
# ⚠️ Trọng Tấn: không xác định được quê quán
# ✅ Khánh Linh: tìm thấy quê quán Hà Nội
# ✅ Bùi Anh Tuấn: tìm thấy quê quán Hà Nội
# ✅ Vũ Cát Tường: tìm thấy quê quán An Giang
# ✅ Đinh Mạnh Ninh: tìm thấy quê quán Hà Nội
# ✅ Bích Phương: tìm thấy quê quán Quảng Ninh
# ✅ Min (ca sĩ Việt Nam): tìm thấy quê quán Hà Nội
# ⚠️ Nguyên Thảo (ca sĩ): không xác định được quê quán
# ✅ Trương Ngọc Ninh: tìm thấy quê quán Nam Định
# ✅ Bằng Kiều: tìm thấy quê quán Hà Nội
# ⚠️ Cẩm Vân (ca sĩ): không xác định được quê quán
# ⚠️ Thuận Yến: không xác định được quê quán
# ⚠️ Duy Thái: không xác định được quê quán
# ⚠️ Bảo Phúc: không xác định được quê quán
# ✅ Nguyễn Cường: tìm thấy quê quán Hà Nội
# ⚠️ Đức Trí: không xác định được quê quán
# ✅ Trần Mạnh Tuấn: tìm thấy quê quán Hà Nội
# ✅ Lê Minh Sơn: tìm thấy quê quán Hà Nội
# ✅ Đỗ Bảo: tìm thấy quê quán Hà Nội
# ⚠️ Hoài Sa: không xác định được quê quán
# ✅ Nguyễn Vĩnh Tiến: tìm thấy quê quán Phú Thọ
# ✅ Khánh Ly: tìm thấy quê quán Hà Nội
# ⚠️ Đăng Dương: không xác định được quê quán
# ✅ Hà Lê: tìm thấy quê quán Hà Nội
# ✅ Phan Mạnh Quỳnh: tìm thấy quê quán Nghệ An
# ⚠️ Orange (ca sĩ): không xác định được quê quán
# ✅ Nguyễn Phúc Thiện: tìm thấy quê quán Đà Nẵng
# ⚠️ Minh Hằng: không xác định được quê quán
# ⚠️ Bảo Thy: không xác định được quê quán
# ✅ Isaac (ca sĩ): tìm thấy quê quán Cần Thơ
# ✅ Hương Tràm: tìm thấy quê quán Nghệ An
# ✅ Ưng Hoàng Phúc: tìm thấy quê quán An Giang
# ✅ Emily (ca sĩ Việt Nam): tìm thấy quê quán Hà Nội
# ⚠️ Andree Right Hand: không xác định được quê quán
# ✅ Touliver: tìm thấy quê quán Hà Nội
# ✅ Binz (rapper): tìm thấy quê quán Gia Lai
# ⚠️ Tóc Tiên (ca sĩ): không xác định được quê quán
# ✅ Tiên Tiên: tìm thấy quê quán Lâm Đồng
# ⚠️ Suboi: không xác định được quê quán
# ⚠️ Wowy: không xác định được quê quán
# ✅ Tlinh: tìm thấy quê quán Hà Nội
# ✅ Rhyder: tìm thấy quê quán Thanh Hóa
# ⚠️ Dế Choắt (rapper): không xác định được quê quán
# ⚠️ Thanh Tuyền (ca sĩ): không xác định được quê quán
# ⚠️ Giao Linh (ca sĩ): không xác định được quê quán
# ⚠️ Thiên Trang: không xác định được quê quán
# ⚠️ Bằng Giang (nhạc sĩ): không xác định được quê quán
# ⚠️ Trường Vũ (ca sĩ): không xác định được quê quán
# ⚠️ Đan Nguyên: không xác định được quê quán
# ⚠️ Duy Khánh: không xác định được quê quán
# ⚠️ Hùng Cường (nghệ sĩ): không xác định được quê quán
# ⚠️ Châu Kỳ: không xác định được quê quán
# ✅ Trúc Phương: tìm thấy quê quán Vĩnh Long
# ⚠️ Trương Hoàng Xuân: không xác định được quê quán
# ⚠️ Nhật Ngân: không xác định được quê quán
# ⚠️ Mộng Long: không xác định được quê quán
# ⚠️ Thanh Phong (ca sĩ): không xác định được quê quán
# ⚠️ Phượng Mai: không xác định được quê quán
# ⚠️ Tuấn Vũ: không xác định được quê quán
# ⚠️ Sơn Tuyền: không xác định được quê quán
# ⚠️ Phương Dung: không xác định được quê quán
# ⚠️ Thái Châu (ca sĩ): không xác định được quê quán
# ✅ Phi Nhung: tìm thấy quê quán Gia Lai
# ⚠️ Băng Châu: không xác định được quê quán
# ⚠️ Trường Vũ (ca sĩ): không xác định được quê quán
# ⚠️ Đinh Việt Lang: không xác định được quê quán
# ⚠️ Trịnh Lâm Ngân: không xác định được quê quán
# ⚠️ Văn Giảng: không xác định được quê quán
# ⚠️ Huỳnh Anh (nhạc sĩ): không xác định được quê quán
# ⚠️ Lê Minh Bằng: không xác định được quê quán
# ⚠️ Ngân Giang (nhạc sĩ): không xác định được quê quán
# ⚠️ Vinh Sử: không xác định được quê quán
# ⚠️ Thanh Bình (nhạc sĩ): không xác định được quê quán
# ✅ Y Vũ: tìm thấy quê quán Hà Nội
# ⚠️ Anh Bằng: không xác định được quê quán
# ⚠️ Chế Linh: không xác định được quê quán
# ⚠️ Trầm Tử Thiêng: không xác định được quê quán
# ⚠️ Tâm Anh: không xác định được quê quán
# ✅ Phạm Thế Mỹ: tìm thấy quê quán Bình Định
# ✅ Lê Trọng Nguyễn: tìm thấy quê quán Quảng Nam
# ⚠️ Ngọc Sơn (nhạc sĩ trước 1975): không xác định được quê quán
# ⚠️ Trần Trịnh: không xác định được quê quán
# ⚠️ Huy Phong: không xác định được quê quán
# ⚠️ Hồng Ngọc (ca sĩ): không xác định được quê quán
# ✅ Siu Black: tìm thấy quê quán Kon Tum
# ✅ Ánh Tuyết: tìm thấy quê quán Quảng Nam
# ✅ Lê Cát Trọng Lý: tìm thấy quê quán Đà Nẵng
# ✅ Tô Thanh Tùng: tìm thấy quê quán Đồng Tháp
# ⚠️ Bảo Yến: không xác định được quê quán
# ⚠️ Duy Mạnh: không xác định được quê quán
# ✅ Hương Giang Idol: tìm thấy quê quán Hà Nội
# ⚠️ Lê Uyên: không xác định được quê quán
# ✅ Trúc Nhân: tìm thấy quê quán Bình Định
# ⚠️ Trúc Hồ: không xác định được quê quán
# ⚠️ Nguyễn Ánh 9: không xác định được quê quán
# ⚠️ WanBi Tuấn Anh: không xác định được quê quán
# ⚠️ Vân Khánh (ca sĩ): không xác định được quê quán
# ⚠️ Nguyên Vũ (ca sĩ): không xác định được quê quán
# ✅ Thanh Thúy (ca sĩ sinh 1977): tìm thấy quê quán Trà Vinh
# ✅ Nguyễn Thiện Nhân (ca sĩ): tìm thấy quê quán Bình Định
# ⚠️ Hồ Văn Cường (ca sĩ): không xác định được quê quán
# ✅ Tố My: tìm thấy quê quán Đà Nẵng
# ✅ Jack: tìm thấy quê quán Bến Tre
# ⚠️ Thanh Thảo (ca sĩ): không xác định được quê quán
# ✅ Lữ Liên: tìm thấy quê quán Hải Phòng
# ⚠️ Bích Chiêu: không xác định được quê quán
# ✅ Anh Tú (sinh 1950): tìm thấy quê quán Lâm Đồng
# ✅ Khánh Hà (ca sĩ): tìm thấy quê quán Lâm Đồng
# ✅ Lưu Bích: tìm thấy quê quán Lâm Đồng
# ⚠️ Thái Hiền: không xác định được quê quán
# ⚠️ Tấn Minh: không xác định được quê quán
# ⚠️ Hồ Trung Dũng: không xác định được quê quán
# ⚠️ Thái Thảo: không xác định được quê quán
# ⚠️ Phạm Duy: không xác định được quê quán
# ✅ Trần Thái Hòa: tìm thấy quê quán Đắk Lắk
# ✅ Thanh Hà (ca sĩ): tìm thấy quê quán Đà Nẵng
# ⚠️ Nguyễn Cao Kỳ Duyên (người dẫn chương trình): không xác định được quê quán

# %%
import json
with open('../raw_data/singer_demo.json', 'w', encoding='utf-8') as f:
    json.dump(singers, f, ensure_ascii=False, indent=4)
